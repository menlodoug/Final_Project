# %%
import numpy as np
import pandas as pd
import datetime as dt
from pathlib import Path
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
import sqlalchemy
from sqlalchemy import and_
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.engine import reflection
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, MetaData
from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/covid_19_ca"
engine = create_engine(db_string)

# %%
# Save references to each table
ca_convid_data = pd.read_sql_table('california_state_cases', con=engine)
ca_convid_data
# Out:
#           date  case_day  death_day
# 0   2020-01-25         1          0
# 1   2020-01-26         1          0
# 2   2020-01-27         0          0
# 3   2020-01-28         0          0
# 4   2020-01-29         0          0
# ..         ...       ...        ...
# 132 2020-06-05      3593         66
# 133 2020-06-06      2637         76
# 134 2020-06-07      2850         27
# 135 2020-06-08      2290         26
# 136 2020-06-09      2943         96
#
# [137 rows x 3 columns]

# %%
import datetime as dt
ca_convid_data['date'] = pd.to_datetime(ca_convid_data['date'])
# set the date as index
ca_convid_data = ca_convid_data.set_index(['date'])
ca_convid_data
# Out:
#             case_day  death_day
# date
# 2020-01-25         1          0
# 2020-01-26         1          0
# 2020-01-27         0          0
# 2020-01-28         0          0
# 2020-01-29         0          0
# ...              ...        ...
# 2020-06-05      3593         66
# 2020-06-06      2637         76
# 2020-06-07      2850         27
# 2020-06-08      2290         26
# 2020-06-09      2943         96
#
# [137 rows x 2 columns]

# %% [markdown]
# # Predict cases based on previous cases alone

# %%
# Showing the autocorrelation for cases
cases = ca_convid_data.drop(["death_day"], axis=1)

# %%
cases.plot()
plt.show()

# %%
autocorrelation_plot(cases)
pyplot.show()

# %% [markdown]
# ##### There is a positive correlation until the 45 lag. A good starting point for the AR (q) parameter of the model may be 20

# %%
# calculating d - the minimum number of differencing needed to make the series stationary
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True)
axes[0, 0].plot(cases.values); axes[0, 0].set_title('Original Series')
autocorrelation_plot(cases, ax=axes[0, 1])

# 1st Differencing
axes[1, 0].plot(cases.diff().values); axes[1, 0].set_title('1st Order Differencing')
autocorrelation_plot(cases.diff().dropna(), ax=axes[1, 1])

# 2nd Differencing
axes[2, 0].plot(cases.diff().diff().values); axes[2, 0].set_title('2nd Order Differencing')
autocorrelation_plot(cases.diff().diff().dropna(), ax=axes[2, 1])

plt.show()

# %%
## Apply decomposition to show trends, sesonality and cyclity
## decomposition = seasonal_decompose(cases, model='multiplicative')

# %% [markdown]
# ## Render data stationary

# %%
# using 35 as window for rolling mean since up to that point the numbers have a slow increase rate

# %%
def get_stationarity(timeseries, key):
    
    # rolling statistics
    rolling_mean = timeseries.rolling(window=35).mean()
    rolling_std = timeseries.rolling(window=35).std()
    
    # rolling statistics plot
    original = pyplot.plot(timeseries, color='blue', label='Original')
    mean = pyplot.plot(rolling_mean, color='red', label='Rolling Mean')
    std = pyplot.plot(rolling_std, color='black', label='Rolling Std')
    pyplot.legend(loc='best')
    pyplot.title('Rolling Mean & Standard Deviation')
    pyplot.show(block=False)
    
    # Dickey–Fuller test:
    result = adfuller(timeseries[key])
    print('ADF Statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {}'.format(key, value))

# %%
# check if the data is stationary using the rolling statistics
get_stationarity(cases, "case_day")
# Out:
# ADF Statistic: 0.8877072635360513
# p-value: 0.9929277874532669
# Critical Values:
# 	1%: -3.4816817173418295
# 	5%: -2.8840418343195267
# 	10%: -2.578770059171598

# %%
# take logs of data 
from numpy import log
cases_log_df = log(cases)
cases_log_df.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-91208908067a> in <module>
#       1 # take logs of data
#       2 from numpy import log
# ----> 3 cases_log_df = log(cases)
#       4 cases_log_df.plot()
#       5 plt.show()
#
# NameError: name 'cases' is not defined

# %% [markdown]
# The rolling mean and rolling standard deviation increase with time. The ADF Statistic is far from the critical values and the p-value is greater than the threshold (0.05). Thus, we can conclude that the time series is not stationary and differencing is needed.

# %%
# add one differentiation
get_stationarity(cases.diff().dropna(), "case_day")
# Out:
# ADF Statistic: -4.467804016958387
# p-value: 0.00022472737773262491
# Critical Values:
# 	1%: -3.4851223522012855
# 	5%: -2.88553750045158
# 	10%: -2.5795685622144586

# %% [markdown]
# #### The p-value is under 0.05 and the ADF statistics is close to critical values. I am going to tentatively fix the order of differencing as 1 even though the series is not perfectly stationary (weak stationarity)

# %% [markdown]
# #### Setting MA term (q) to 2 since we can see in the autocrelation plot for 1 differentiation 2 values outside the boundries

# %% [markdown]
# ### Training the ARIMA model

# %%
model = ARIMA(cases, order=(8,1,1))
model_fit = model.fit(disp=0)
pyplot.plot(cases)
pyplot.plot(model_fit.fittedvalues, color='red')
print(model_fit.summary())
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.case_day   No. Observations:                  136
# Model:                 ARIMA(8, 1, 1)   Log Likelihood                -956.683
# Method:                       css-mle   S.D. of innovations            273.169
# Date:                Sun, 14 Jun 2020   AIC                           1935.367
# Time:                        23:19:36   BIC                           1967.406
# Sample:                    01-26-2020   HQIC                          1948.387
#                          - 06-09-2020
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               20.7821      7.864      2.643      0.008       5.370      36.194
# ar.L1.D.case_day    -0.0655      0.376     -0.174      0.862      -0.802       0.671
# ar.L2.D.case_day    -0.1473      0.248     -0.593      0.553      -0.634       0.339
# ar.L3.D.case_day    -0.1593      0.204     -0.781      0.435      -0.559       0.241
# ar.L4.D.case_day    -0.0313      0.193     -0.162      0.871      -0.409       0.347
# ar.L5.D.case_day    -0.1922      0.145     -1.325      0.185      -0.476       0.092
# ar.L6.D.case_day     0.1707      0.167      1.025      0.305      -0.156       0.497
# ar.L7.D.case_day     0.1711      0.093      1.846      0.065      -0.011       0.353
# ar.L8.D.case_day     0.0120      0.102      0.118      0.906      -0.188       0.212
# ma.L1.D.case_day    -0.5870      0.366     -1.604      0.109      -1.304       0.130
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.6737           -0.9174j            1.1382           -0.1492
# AR.2            0.6737           +0.9174j            1.1382            0.1492
# AR.3            1.3683           -0.0000j            1.3683           -0.0000
# AR.4           -0.3576           -1.1363j            1.1912           -0.2985
# AR.5           -0.3576           +1.1363j            1.1912            0.2985
# AR.6           -1.5912           -0.0536j            1.5921           -0.4946
# AR.7           -1.5912           +0.0536j            1.5921            0.4946
# AR.8          -13.0167           -0.0000j           13.0167           -0.5000
# MA.1            1.7037           +0.0000j            1.7037            0.0000
# -----------------------------------------------------------------------------

# %%
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
residuals.plot()
pyplot.show()
residuals.plot(kind='kde')
pyplot.show()
print(residuals.describe())
# Out:
#                  0
# count   136.000000
# mean     -0.355401
# std     274.201634
# min    -616.754383
# 25%     -71.266184
# 50%     -57.962998
# 75%      78.665568
# max    1174.473962

# %%
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
# predict data
model_fit.plot_predict(1,160)

# %%
from statsmodels.tsa.stattools import acf

# Create Training and Test
train = cases[:110]
test = cases[110:]

# %%
test_model = ARIMA(train, order=(10,1,1))
test_model_fit = model.fit(disp=0)
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
# Forecast
fc, se, conf = test_model_fit.forecast(27, alpha=0.05)

# %%
# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
fc
# Out:
# array([2614.3835907 , 3046.74494343, 2989.50836312, 2980.78212301,
#        2760.83431053, 2879.30789618, 2898.72094435, 2977.56374325,
#        3045.25941289, 3084.41729999, 3022.02739893, 3011.66125521,
#        3044.76224263, 3083.83971148, 3123.56302349, 3167.26531683,
#        3175.95463033, 3168.87212387, 3181.27324392, 3209.13413806,
#        3237.61108218, 3268.74934956, 3294.29377132, 3306.8531902 ,
#        3317.8785423 , 3337.38863315, 3361.28573306])

# %%
test["case_day"].values
# Out:
# array([1729, 2068, 1918, 1433, 1577, 2038, 2144, 2363, 2313, 2014, 1928,
#        2274, 2908, 1949, 2197, 2972, 3057, 3014, 2529, 2438, 2326, 2510,
#        3593, 2637, 2850, 2290, 2943])

# %%
# Accuracy metrics
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-actual)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test["case_day"].values)
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning
# {'mape': 0.359848312989031,
#  'me': 725.1087412586954,
#  'mae': 747.23512856804,
#  'mpe': 0.3536901200278998,
#  'rmse': 826.9133654340886,
#  'acf1': 0.2999962180373141,
#  'corr': 0.6804691557965685,
#  'minmax': 0.24449340217941062}

# %% [markdown]
# Arround 36% MAPE indicate the model is acurate 64% of the time which is not a very good model.
# The lack of sufficient datapoints and other factors beside previous cases may affect the total number of cases

# %% [markdown]
# ### Auto Arima Forecast in Python

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
model = pm.auto_arima(cases, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=1937.251, BIC=1948.902, Time=0.125 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=1980.020, BIC=1985.845, Time=0.012 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=1962.072, BIC=1970.810, Time=0.032 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=1937.339, BIC=1946.077, Time=0.083 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=False]; AIC=1978.551, BIC=1981.464, Time=0.008 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=1938.507, BIC=1953.070, Time=0.212 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=1939.184, BIC=1953.747, Time=0.170 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=1936.961, BIC=1948.612, Time=0.122 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=1938.875, BIC=1953.438, Time=0.230 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=1940.961, BIC=1958.437, Time=0.387 seconds
# Near non-invertible roots for order (1, 1, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 1.390 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  137
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -964.480
# Date:                Sun, 14 Jun 2020   AIC                           1936.961
# Time:                        23:19:41   BIC                           1948.612
# Sample:                             0   HQIC                          1941.696
#                                 - 137
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     21.1274      7.406      2.853      0.004       6.613      35.642
# ma.L1         -0.6234      0.074     -8.369      0.000      -0.769      -0.477
# ma.L2         -0.1288      0.091     -1.412      0.158      -0.308       0.050
# sigma2      8.416e+04   9030.981      9.320      0.000    6.65e+04    1.02e+05
# ===================================================================================
# Ljung-Box (Q):                       72.28   Jarque-Bera (JB):                96.17
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              28.02   Skew:                             1.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(7,5))
plt.show()

# %% [markdown]
# Top left: The residual errors seem to fluctuate around and the is not an uniform variance.
#
# Top Right: The density plot suggest skewed distribution.
#
# Bottom left: All the dots don't perfectly in line with the red line. Significant deviations imply the distribution is skewed.
#
# Bottom Right: The Correlogram, aka,show autocorrelation, that implies that there are some pattern in the residual errors which are not explained in the model. So we need to look for more X’s (predictors) to the model.
