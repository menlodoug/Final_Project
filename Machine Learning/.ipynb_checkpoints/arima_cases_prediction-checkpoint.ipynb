# %%
import numpy as np
import pandas as pd
import datetime as dt
from pathlib import Path
from matplotlib import pyplot
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
import sqlalchemy
from sqlalchemy import and_
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.engine import reflection
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, MetaData

# %%
import sys
sys.path.insert(1, '../')

# Now do your import
from config import db_password

# %%
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/covid_19_ca"
engine = create_engine(db_string)

# %%
# Save references to each table
ca_convid_data = pd.read_sql_table('california_state_cases', con=engine)
ca_convid_data
# Out:
#           date  case_day  death_day
# 0   2020-01-25         1          0
# 1   2020-01-26         1          0
# 2   2020-01-27         0          0
# 3   2020-01-28         0          0
# 4   2020-01-29         0          0
# ..         ...       ...        ...
# 132 2020-06-05      3593         66
# 133 2020-06-06      2637         76
# 134 2020-06-07      2850         27
# 135 2020-06-08      2290         26
# 136 2020-06-09      2943         96
#
# [137 rows x 3 columns]

# %%
import datetime as dt
ca_convid_data['date'] = pd.to_datetime(ca_convid_data['date'])
# set the date as index
ca_convid_data = ca_convid_data.set_index(['date'])

# %% [markdown]
# # Predict cases based on previous cases alone

# %%
# Showing the autocorrelation for cases
cases = ca_convid_data.drop(["death_day"], axis=1)

# %%
# # removing the first 40 data points
# cases = cases.iloc[50:]
# cases

# %%
cases.plot()
plt.show()

# %%
autocorrelation_plot(cases)
pyplot.show()

# %% [markdown]
# ##### There is a positive correlation until the 45 lag. A good starting point for the AR (q) parameter of the model may be 20

# %%
# calculating d - the minimum number of differencing needed to make the series stationary
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Original Series
fig, axes = plt.subplots(3, 2, sharex=True, figsize=(40,20))

axes[0, 0].plot(cases.values); axes[0, 0].set_title('Original Series')
plot_acf(cases.values,lags=120, ax=axes[1, 0])
plot_pacf(cases.values,lags=120, ax=axes[2, 0])

# 1st Differencing
diff_one = cases.diff()
axes[0, 1].plot(diff_one.values); axes[0, 1].set_title('1st Order Differencing')
plot_acf(diff_one, lags=120, ax=axes[1, 1])
plot_pacf(diff_one, lags=120, ax=axes[2, 1])

plt.show()
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/regression/linear_model.py:1406: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %% [markdown]
# ## Render data stationary

# %%
# using 35 as window for rolling mean since up to that point the numbers have a slow increase rate

# %%
def get_stationarity(timeseries):
    
    # rolling statistics
    rolling_mean = timeseries.rolling(window=8).mean()
    rolling_std = timeseries.rolling(window=8).std()
    
    # rolling statistics plot
    original = pyplot.plot(timeseries, color='blue', label='Original')
    mean = pyplot.plot(rolling_mean, color='red', label='Rolling Mean')
    std = pyplot.plot(rolling_std, color='black', label='Rolling Std')
    pyplot.legend(loc='best')
    pyplot.title('Rolling Mean & Standard Deviation')
    pyplot.show(block=False)
    
    # Dickey–Fuller test:
    result = adfuller(timeseries)
    print('ADF Statistic: {}'.format(result[0]))
    print('p-value: {}'.format(result[1]))
    print('Critical Values:')
    for key, value in result[4].items():
        print('\t{}: {}'.format(key, value))

# %%
# check if the data is stationary using the rolling statistics
get_stationarity(cases["case_day"])
# Out:
# ADF Statistic: 0.8877072635360513
# p-value: 0.9929277874532669
# Critical Values:
# 	1%: -3.4816817173418295
# 	5%: -2.8840418343195267
# 	10%: -2.578770059171598

# %% [markdown]
# The rolling mean and rolling standard deviation increase with time. The ADF Statistic is far from the critical values and the p-value is greater than the threshold (0.05). Thus, we can conclude that the time series is not stationary and differencing is needed.

# %%
# take logs of data 
from numpy import log
# adding a constant to ensure all the values are above 0
const = 1;
cases_log = log(const + cases)
cases_log
# Out:
#             case_day
# date
# 2020-01-25  0.693147
# 2020-01-26  0.693147
# 2020-01-27  0.000000
# 2020-01-28  0.000000
# 2020-01-29  0.000000
# ...              ...
# 2020-06-05  8.187021
# 2020-06-06  7.877776
# 2020-06-07  7.955425
# 2020-06-08  7.736744
# 2020-06-09  7.987524
#
# [137 rows x 1 columns]

# %%
cases_log.plot()
plt.show()

# %%
autocorrelation_plot(cases_log)
pyplot.show()

# %%
# check if the data is stationary using the rolling statistics
get_stationarity(cases_log["case_day"])
# Out:
# ADF Statistic: -2.3998110269432074
# p-value: 0.14178975203972116
# Critical Values:
# 	1%: -3.484219653271961
# 	5%: -2.885145235641637
# 	10%: -2.579359138917794

# %%
# add one differentiation
cases_diff_one = cases.diff().dropna()
get_stationarity(cases_diff_one["case_day"])
# Out:
# ADF Statistic: -4.467804016958387
# p-value: 0.00022472737773262491
# Critical Values:
# 	1%: -3.4851223522012855
# 	5%: -2.88553750045158
# 	10%: -2.5795685622144586

# %%
# add two differentiation
cases_diff_two = cases.diff().diff().dropna()
get_stationarity(cases_diff_two["case_day"])
# Out:
# ADF Statistic: -4.52840634584849
# p-value: 0.00017466113153794227
# Critical Values:
# 	1%: -3.485585145896754
# 	5%: -2.885738566292665
# 	10%: -2.5796759080663887

# %% [markdown]
# #### The p-value is under 0.05 and the ADF statistics is close to critical values. I am going to tentatively fix the order of differencing as 1 even though the series is not perfectly stationary (weak stationarity)

# %%
# add two differentiation
cases_diff_three = cases.diff().diff().diff().dropna()
get_stationarity(cases_diff_three["case_day"])
# Out:
# ADF Statistic: -10.39638938311517
# p-value: 1.960229728515552e-18
# Critical Values:
# 	1%: -3.4851223522012855
# 	5%: -2.88553750045158
# 	10%: -2.5795685622144586

# %%
# case log one diff
cases_log_diff_one = cases_log.diff().dropna()
get_stationarity(cases_log_diff_one["case_day"])
# Out:
# ADF Statistic: -1.4992515974033835
# p-value: 0.5338815304337513
# Critical Values:
# 	1%: -3.484219653271961
# 	5%: -2.885145235641637
# 	10%: -2.579359138917794

# %%
# case log two diff
cases_log_diff_two = cases_log.diff().diff().dropna()
get_stationarity(cases_log_diff_two["case_day"])
# Out:
# ADF Statistic: -7.825436051388283
# p-value: 6.500714676663751e-12
# Critical Values:
# 	1%: -3.484219653271961
# 	5%: -2.885145235641637
# 	10%: -2.579359138917794

# %%
# case log three diff
cases_log_diff_three = cases_log.diff().diff().diff().dropna()
get_stationarity(cases_log_diff_three["case_day"])
# Out:
# ADF Statistic: -7.37865870735482
# p-value: 8.587679591661632e-11
# Critical Values:
# 	1%: -3.486055829282407
# 	5%: -2.8859430324074076
# 	10%: -2.5797850694444446

# %% [markdown]
# ### Training the ARIMA model

# %% [markdown]
# #### Setting MA term (q) to 2 since we can see in the autocrelation plot for 1 differentiation 2 values outside the boundries

# %%
# using the pacf plot to determine the p values
# we use the amount of lags outside the  
p = 20
# d for the level of differentiation needed
# since the data is not stationary we use 2 level of differenciation
d = 2
q = 0
model = ARIMA(cases, order=(p,d,q))
model_fit = model.fit(disp=0)
pyplot.plot(cases, color="blue", label="Current Value")
pyplot.plot(model_fit.fittedvalues, color='red', label="Predicted Values")
pyplot.legend(loc='best')
print(model_fit.summary())
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:162: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:            D2.case_day   No. Observations:                  135
# Model:                ARIMA(20, 2, 0)   Log Likelihood                -940.266
# Method:                       css-mle   S.D. of innovations            247.493
# Date:                Tue, 23 Jun 2020   AIC                           1924.532
# Time:                        10:36:08   BIC                           1988.449
# Sample:                    01-27-2020   HQIC                          1950.506
#                          - 06-09-2020
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.2679      0.792      0.338      0.735      -1.284       1.820
# ar.L1.D2.case_day     -1.6314      0.085    -19.211      0.000      -1.798      -1.465
# ar.L2.D2.case_day     -2.0418      0.165    -12.373      0.000      -2.365      -1.718
# ar.L3.D2.case_day     -2.3308      0.243     -9.601      0.000      -2.807      -1.855
# ar.L4.D2.case_day     -2.3774      0.315     -7.552      0.000      -2.994      -1.760
# ar.L5.D2.case_day     -2.3938      0.371     -6.452      0.000      -3.121      -1.667
# ar.L6.D2.case_day     -2.1619      0.415     -5.204      0.000      -2.976      -1.348
# ar.L7.D2.case_day     -1.7581      0.441     -3.991      0.000      -2.621      -0.895
# ar.L8.D2.case_day     -1.5354      0.450     -3.413      0.001      -2.417      -0.654
# ar.L9.D2.case_day     -1.3985      0.456     -3.065      0.002      -2.293      -0.504
# ar.L10.D2.case_day    -1.2563      0.460     -2.732      0.006      -2.158      -0.355
# ar.L11.D2.case_day    -1.2533      0.459     -2.731      0.006      -2.153      -0.354
# ar.L12.D2.case_day    -1.3023      0.455     -2.859      0.004      -2.195      -0.410
# ar.L13.D2.case_day    -1.4716      0.449     -3.277      0.001      -2.352      -0.591
# ar.L14.D2.case_day    -1.4874      0.440     -3.377      0.001      -2.350      -0.624
# ar.L15.D2.case_day    -1.1690      0.418     -2.794      0.005      -1.989      -0.349
# ar.L16.D2.case_day    -0.8500      0.376     -2.264      0.024      -1.586      -0.114
# ar.L17.D2.case_day    -0.5202      0.326     -1.598      0.110      -1.158       0.118
# ar.L18.D2.case_day    -0.2772      0.257     -1.077      0.281      -0.782       0.227
# ar.L19.D2.case_day    -0.2183      0.177     -1.232      0.218      -0.565       0.129
# ar.L20.D2.case_day    -0.1865      0.093     -2.014      0.044      -0.368      -0.005
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1            -1.0416           -0.1466j            1.0519           -0.4778
# AR.2            -1.0416           +0.1466j            1.0519            0.4778
# AR.3            -0.9744           -0.4628j            1.0787           -0.4294
# AR.4            -0.9744           +0.4628j            1.0787            0.4294
# AR.5            -0.8497           -0.6875j            1.0930           -0.3917
# AR.6            -0.8497           +0.6875j            1.0930            0.3917
# AR.7            -0.5207           -0.8940j            1.0346           -0.3339
# AR.8            -0.5207           +0.8940j            1.0346            0.3339
# AR.9            -0.2391           -1.0041j            1.0322           -0.2872
# AR.10           -0.2391           +1.0041j            1.0322            0.2872
# AR.11            0.0271           -1.1117j            1.1120           -0.2461
# AR.12            0.0271           +1.1117j            1.1120            0.2461
# AR.13            0.3652           -0.9576j            1.0249           -0.1920
# AR.14            0.3652           +0.9576j            1.0249            0.1920
# AR.15            0.6798           -0.7671j            1.0250           -0.1346
# AR.16            0.6798           +0.7671j            1.0250            0.1346
# AR.17            1.0019           -0.3768j            1.0704           -0.0573
# AR.18            1.0019           +0.3768j            1.0704            0.0573
# AR.19            0.9664           -1.0106j            1.3983           -0.1286
# AR.20            0.9664           +1.0106j            1.3983            0.1286
# ------------------------------------------------------------------------------

# %% [markdown]
# ### Model diagnostics

# %%
# plot residual errors
# get all the patterns should be captured
# by the model
# only randomess should be in the residuals
residuals = pd.DataFrame(model_fit.resid)
# residuals.plot()
# pyplot.show()
# residuals.plot(kind='kde')
# pyplot.show()

residuals
# Plot residuals
# fig, axes = plt.subplots(2, 1, sharex=True, figsize=(40,20))
fig = plt.figure(figsize=(12, 8))
ax1 = fig.add_subplot()
# # acf plot for autocorrelation
fig = plot_acf(model_fit.resid, lags=20, ax=ax1)

from scipy.stats import norm
# histogram for distribution
ax2 = fig.add_subplot(211)
ax2.hist(residuals, bins="auto", density=True, rwidth=0.75);
ax2.set_title('Residuals')
# plot the bell curve
# calculate the mean and the standart deviation
mu, std = norm.fit(residuals)

xmin, xmax = ax2.xlim()

# probability density function
p = norm.pdf(x, mu, std)

# evenly divides the spece between the min and mac
x = np.linespace(xmin, xmax, 100)

ax2.plot(x, p, "m", linewidth=2)
ax2.grid(axis="y", alpha=2)

plt.show()

# print(residuals.describe())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-6cf63fc014b8> in <module>
#      15 # ax1 = fig.add_subplot()
#      16 # # acf plot for autocorrelation
# ---> 17 fig = plot_acf(model_fit.resid, lags=20, ax=[0, 0])
#      18
#      19 from scipy.stats import norm
#
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/graphics/tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, unbiased, fft, missing, title, zero, vlines_kwargs, **kwargs)
#     143     .. plot:: plots/graphics_tsa_plot_acf.py
#     144     """
# --> 145     fig, ax = utils.create_mpl_ax(ax)
#     146
#     147     lags, nlags, irregular = _prepare_data_corr_plot(x, lags, zero)
#
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/graphics/utils.py in create_mpl_ax(ax)
#      56         ax = fig.add_subplot(111)
#      57     else:
# ---> 58         fig = ax.figure
#      59
#      60     return fig, ax
#
# AttributeError: 'list' object has no attribute 'figure'

# %%
## We want the mean of the residuals to be close to 0
## Based on acf plot there shoudl be no autocorrelation left
## We don't want more the one leg outside the threshold
## Use the histogram to learn the distribution of the residuals

# %%
# Actual vs Fitted
model_fit.plot_predict(dynamic=False)
plt.show()

# %%
# predict data
model_fit.plot_predict(1,90)

# %%
from statsmodels.tsa.stattools import acf

# Create Training and Test
train = cases[:110]
test = cases[110:]

# %%
# test_model = ARIMA(train, order=(10,1,1))
test_model_fit = model.fit(disp=0)

# %%
# Forecast
fc, se, conf = test_model_fit.forecast(27, alpha=0.05)

# %%
# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
fc
# Out:
# array([2594.2657099 , 2984.26675262, 2944.82851813, 2950.17371168,
#        2801.58971869, 2900.42588096, 2848.93201888, 2912.72645989,
#        2991.18182434, 3065.7150184 , 3007.4263148 , 3029.82882927,
#        3028.29748424, 3037.60773444, 3067.45918058, 3133.27409862,
#        3147.22748306, 3157.85278754, 3173.29085115, 3184.16057004,
#        3193.06780088, 3228.27916842, 3259.50367023, 3279.1660674 ,
#        3298.09334804, 3317.40169515, 3329.22679186])

# %%
test["case_day"].values
# Out:
# array([1729, 2068, 1918, 1433, 1577, 2038, 2144, 2363, 2313, 2014, 1928,
#        2274, 2908, 1949, 2197, 2972, 3057, 3014, 2529, 2438, 2326, 2510,
#        3593, 2637, 2850, 2290, 2943])

# %%
# Accuracy metrics
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))  # MAPE
    me = np.mean(forecast - actual)             # ME
    mae = np.mean(np.abs(forecast - actual))    # MAE
    mpe = np.mean((forecast - actual)/actual)   # MPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE
    corr = np.corrcoef(forecast, actual)[0,1]   # corr
    mins = np.amin(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    maxs = np.amax(np.hstack([forecast[:,None], 
                              actual[:,None]]), axis=1)
    minmax = 1 - np.mean(mins/maxs)             # minmax
    acf1 = acf(fc-actual)[1]                      # ACF1
    return({'mape':mape, 'me':me, 'mae': mae, 
            'mpe': mpe, 'rmse':rmse, 'acf1':acf1, 
            'corr':corr, 'minmax':minmax})

forecast_accuracy(fc, test["case_day"].values)
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:572: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   FutureWarning
# {'mape': 0.3491568073141175,
#  'me': 698.2692403409663,
#  'mae': 722.9726721754888,
#  'mpe': 0.3422813740175625,
#  'rmse': 804.391002678971,
#  'acf1': 0.30929173692762063,
#  'corr': 0.6809157547419445,
#  'minmax': 0.23857449669530784}

# %% [markdown]
# Arround 36% MAPE indicate the model is acurate 64% of the time which is not a very good model.
# The lack of sufficient datapoints and other factors beside previous cases may affect the total number of cases

# %% [markdown]
# ### Auto Arima Forecast in Python

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
model = pm.auto_arima(cases, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
# Fit ARIMA(1,1,1)x(0,0,0,0) [intercept=True]; AIC=1937.251, BIC=1948.902, Time=0.120 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=True]; AIC=1980.020, BIC=1985.845, Time=0.010 seconds
# Fit ARIMA(1,1,0)x(0,0,0,0) [intercept=True]; AIC=1962.072, BIC=1970.810, Time=0.029 seconds
# Fit ARIMA(0,1,1)x(0,0,0,0) [intercept=True]; AIC=1937.339, BIC=1946.077, Time=0.067 seconds
# Fit ARIMA(0,1,0)x(0,0,0,0) [intercept=False]; AIC=1978.551, BIC=1981.464, Time=0.007 seconds
# Fit ARIMA(2,1,1)x(0,0,0,0) [intercept=True]; AIC=1938.507, BIC=1953.070, Time=0.161 seconds
# Fit ARIMA(1,1,2)x(0,0,0,0) [intercept=True]; AIC=1939.184, BIC=1953.747, Time=0.157 seconds
# Near non-invertible roots for order (1, 1, 2)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 0.999)
# Fit ARIMA(0,1,2)x(0,0,0,0) [intercept=True]; AIC=1936.961, BIC=1948.612, Time=0.110 seconds
# Fit ARIMA(0,1,3)x(0,0,0,0) [intercept=True]; AIC=1938.875, BIC=1953.438, Time=0.220 seconds
# Fit ARIMA(1,1,3)x(0,0,0,0) [intercept=True]; AIC=1940.961, BIC=1958.437, Time=0.360 seconds
# Near non-invertible roots for order (1, 1, 3)(0, 0, 0, 0); setting score to inf (at least one inverse root too close to the border of the unit circle: 1.000)
# Total fit time: 1.249 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  137
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -964.480
# Date:                Tue, 23 Jun 2020   AIC                           1936.961
# Time:                        09:24:52   BIC                           1948.612
# Sample:                             0   HQIC                          1941.696
#                                 - 137
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     21.1274      7.406      2.853      0.004       6.613      35.642
# ma.L1         -0.6234      0.074     -8.369      0.000      -0.769      -0.477
# ma.L2         -0.1288      0.091     -1.412      0.158      -0.308       0.050
# sigma2      8.416e+04   9030.981      9.320      0.000    6.65e+04    1.02e+05
# ===================================================================================
# Ljung-Box (Q):                       72.28   Jarque-Bera (JB):                96.17
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              28.02   Skew:                             1.08
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.50
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(7,5))
plt.show()

# %% [markdown]
# Top left: The residual errors seem to fluctuate around and the is not an uniform variance.
#
# Top Right: The density plot suggest skewed distribution.
#
# Bottom left: All the dots don't perfectly in line with the red line. Significant deviations imply the distribution is skewed.
#
# Bottom Right: The Correlogram, aka,show autocorrelation, that implies that there are some pattern in the residual errors which are not explained in the model. So we need to look for more X’s (predictors) to the model.
