# %%
import json
import requests
import pandas as pd
import numpy as np
import re
from sqlalchemy import create_engine
import time

# %%
# extract wiki data
r = requests.get("https://data.cdc.gov/resource/9bhg-hcku.json")
rd = json.loads(r.text)

# %%
o_df = pd.DataFrame(rd)
o_df.tail(10)
# Out:
#                   data_as_of               start_week  \
# 990  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 991  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 992  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 993  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 994  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 995  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 996  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 997  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 998  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
# 999  2020-05-28T00:00:00.000  2020-02-01T00:00:00.000
#
#                     end_week       state           sex          age_group  \
# 990  2020-05-23T00:00:00.000        Ohio        Female        25-34 years
# 991  2020-05-23T00:00:00.000        Ohio        Female        35-44 years
# 992  2020-05-23T00:00:00.000        Ohio        Female        45-54 years
# ...

# %%
# extract second source data
data_2 = pd.read_csv(f'Resources/owid-covid-data.csv', low_memory=False)

# %%
data_2.tail()
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 20761      NaN  International  2020-02-28          705          0
# 20762      NaN  International  2020-02-29          705          0
# 20763      NaN  International  2020-03-01          705          0
# 20764      NaN  International  2020-03-02          705          0
# 20765      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 20761             4           0                      NaN
# 20762             6           2                      NaN
# 20763             6           0                      NaN
# 20764             6           0                      NaN
# 20765             7           1                      NaN
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 20761                    NaN                       NaN  ...            NaN
# ...
