# %%
import pandas as pd
import requests
from pathlib import Path
import matplotlib.pyplot as plt

# %%
def parser(x):
	return pd.to_datetime(x)

case_death_data = pd.read_csv(Path('./Resources/us-states.csv'), header=0, parse_dates=[0], index_col=0, squeeze=True, date_parser=parser)
case_death_data.head()
# Out:
#                  state  fips  cases  deaths
# date
# 2020-01-21  Washington    53      1       0
# 2020-01-22  Washington    53      1       0
# 2020-01-23  Washington    53      1       0
# 2020-01-24    Illinois    17      1       0
# 2020-01-24  Washington    53      1       0

# %%
# Get California data only
ca_case_df = case_death_data.loc[case_death_data['state'] == 'California']
ca_case_df = ca_case_df.drop(columns=["state", "fips"])
ca_case_df
# Out:
#              cases  deaths
# date
# 2020-01-25       1       0
# 2020-01-26       2       0
# 2020-01-27       2       0
# 2020-01-28       2       0
# 2020-01-29       2       0
# ...            ...     ...
# 2020-06-02  118081    4360
# 2020-06-03  120407    4422
# 2020-06-04  122917    4484
# 2020-06-05  126510    4550
# 2020-06-06  129147    4626
#
# [134 rows x 2 columns]

# %%
# add testing data
testing_data = pd.read_csv(Path('./Resources/US_COVID_TESTS.csv'), header=0, parse_dates=[2], index_col=2, squeeze=True, date_parser=parser)
testing_data.head()
# Out:
#            Country/Region Province/State  positive  positiveIncrease  \
# Date
# 2020-03-07  United States        Alabama       0.0                 0
# 2020-03-08  United States        Alabama       0.0                 0
# 2020-03-09  United States        Alabama       0.0                 0
# 2020-03-10  United States        Alabama       0.0                 0
# 2020-03-11  United States        Alabama       0.0                 0
#
#             negative  negativeIncrease  pending  pendingIncrease  death  \
# Date
# 2020-03-07       NaN                 0      NaN              NaN    NaN
# 2020-03-08       NaN                 0      NaN              NaN    NaN
# 2020-03-09       NaN                 0      NaN              NaN    NaN
# 2020-03-10       0.0                 0      0.0              NaN    NaN
# 2020-03-11      10.0                10      NaN              NaN    NaN
#
#             deathIncrease  ...  hospitalizedCumulative  \
# Date                       ...
# 2020-03-07              0  ...                     NaN
# 2020-03-08              0  ...                     NaN
# 2020-03-09              0  ...                     NaN
# 2020-03-10              0  ...                     NaN
# 2020-03-11              0  ...                     NaN
#
#             hospitalizedCumulativeIncrease  inIcuCurrently  \
# Date
# 2020-03-07                             NaN             NaN
# 2020-03-08                             NaN             NaN
# 2020-03-09                             NaN             NaN
# 2020-03-10                             NaN             NaN
# 2020-03-11                             NaN             NaN
#
#             inIcuCurrentlyIncrease inIcuCumulative inIcuCumulativeIncrease  \
# Date
# 2020-03-07                     NaN             NaN                     NaN
# 2020-03-08                     NaN             NaN                     NaN
# 2020-03-09                     NaN             NaN                     NaN
# 2020-03-10                     NaN             NaN                     NaN
# 2020-03-11                     NaN             NaN                     NaN
#
#            onVentilatorCurrently  onVentilatorCurrentlyIncrease  \
# Date
# 2020-03-07                   NaN                            NaN
# 2020-03-08                   NaN                            NaN
# 2020-03-09                   NaN                            NaN
# 2020-03-10                   NaN                            NaN
# 2020-03-11                   NaN                            NaN
#
#             onVentilatorCumulative  onVentilatorCumulativeIncrease
# Date
# 2020-03-07                     NaN                             NaN
# 2020-03-08                     NaN                             NaN
# 2020-03-09                     NaN                             NaN
# 2020-03-10                     NaN                             NaN
# 2020-03-11                     NaN                             NaN
#
# [5 rows x 30 columns]

# %%
all_testing_ca = testing_data[testing_data["Province/State"] == "California"]
testing_ca = all_testing_ca.drop(columns=[
    'Country/Region',
     'Province/State',
     'pending',
     'pendingIncrease',
     'death',
     'deathIncrease',
     'hospitalized',
     'hospitalizedIncrease',
     'ISO3166-1',
     'ISO3166-2',
     'Last_Update_Date',
     'Last_Reported_Flag',
     'hospitalizedCurrently',
     'hospitalizedCurrentlyIncrease',
     'hospitalizedCumulative',
     'hospitalizedCumulativeIncrease',
     'inIcuCurrently',
     'inIcuCurrentlyIncrease',
     'inIcuCumulative',
     'inIcuCumulativeIncrease',
     'onVentilatorCurrently',
     'onVentilatorCurrentlyIncrease',
     'onVentilatorCumulative',
     'onVentilatorCumulativeIncrease'
])

# %%
testing_ca.plot()
plt.show()

# %%
# add mobility data
# Global_Mobility_Report.csv
mobility_raw = pd.read_excel('./Resources/Global_Mobility_Report.xlsx', index_col=0)

# %%
state_mobility = mobility_raw[mobility_raw["county"].isnull()]

# %%
# transform the date to datetime
import datetime as dt
state_mobility['datetime'] = pd.to_datetime(state_mobility['date'])
# Out:
# /usr/local/anaconda3/envs/Python3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# set the date as index
state_mobility = state_mobility.set_index(['datetime'])

# %%
# remove the country, date columns
state_mobility = state_mobility.drop(columns=["county", "date"])

# %%
# plot the data
state_mobility.plot()
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
# join all table in one 
ca_data = testing_ca.merge(state_mobility, left_index=True, right_index=True).merge(ca_case_df, left_index=True, right_index=True)

# %%
ca_data
# Out:
#             positive  positiveIncrease   negative  negativeIncrease    total  \
# 2020-03-04      53.0                 0      462.0                 0      515
# 2020-03-05      53.0                 0      462.0                 0      515
# 2020-03-06      60.0                 7      462.0                 0      522
# 2020-03-07      69.0                 9      462.0                 0      531
# 2020-03-08      88.0                19      462.0                 0      550
# ...              ...               ...        ...               ...      ...
# 2020-05-25   94558.0              1848  1549544.0             59509  1644102
# 2020-05-26   96733.0              2175  1599663.0             50119  1696396
# 2020-05-27   98980.0              2247  1637914.0             38251  1736894
# 2020-05-28  101697.0              2717  1688862.0             50948  1790559
# 2020-05-29  103886.0              2189  1731592.0             42730  1835478
